# %%
import numpy as np
import tensorflow as tf

# %%
(train_data, train_label), (test_data, test_label) = tf.keras.datasets.boston_housing.load_data()

# %%
train_data.shape
# Out:
# (404, 13)

# %%
train_label.shape
# Out:
# (404,)

# %%
with tf.Graph().as_default() as g:
    inputs = tf.placeholder(shape = [None, 13], dtype=tf.float32)
    labels = tf.placeholder(shape = [None], dtype=tf.float32)
    
    h1 = tf.keras.layers.Dense(64, activation=tf.nn.relu)(inputs)
    h2 = tf.keras.layers.Dense(16, activation=tf.nn.relu)(h1)
    output = tf.keras.layers.Dense(1, activation=None)(h2)
    
    loss = tf.reduce_mean(tf.keras.losses.mean_squared_error(labels, output))
    
    optim = tf.train.GradientDescentOptimizer(learning_rate=1e-6)
    train_op = optim.minimize(loss)

with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    batch_size = 32
    for epoch in range(200):
        order = np.argsort(np.random.random(train_label.shape))
        #np.argsort 返回元素从小到大排列的索引
        train_data = train_data[order]
        train_label = train_label[order]
        
        res_train_losses = []
        for i in range(train_label.shape[0] // batch_size):
            start = i * batch_size
            end = (i + 1) * batch_size
            res_train_loss, _ = sess.run([loss, train_op], feed_dict={inputs: train_data[start: end], labels: train_label[start: end]})
            res_train_losses.append(res_train_loss)
        res_val_loss = sess.run(loss, feed_dict={inputs: test_data, labels: test_label})
        print('epoch %3d, train loss %2.4f, val loss %2.4f' % (epoch, res_train_loss, np.mean(res_train_losses)))
# Out:
# epoch   0, train loss 128.8053, val loss 239.9913
# epoch   1, train loss 142.9555, val loss 117.1986
# epoch   2, train loss 107.6159, val loss 119.4852
# epoch   3, train loss 115.5692, val loss 108.5080
# epoch   4, train loss 117.9148, val loss 103.2312
# epoch   5, train loss 147.6217, val loss 107.0723
# epoch   6, train loss 76.1409, val loss 103.5839
# epoch   7, train loss 157.1785, val loss 107.8412
# epoch   8, train loss 91.4189, val loss 103.3456
# epoch   9, train loss 97.2522, val loss 105.2391
# epoch  10, train loss 75.3154, val loss 98.3508
# epoch  11, train loss 98.6424, val loss 101.6590
# epoch  12, train loss 23.8769, val loss 104.3538
# epoch  13, train loss 90.3902, val loss 97.4422
# epoch  14, train loss 103.8977, val loss 103.9320
# epoch  15, train loss 106.3953, val loss 99.8915
# epoch  16, train loss 161.6240, val loss 104.7156
# epoch  17, train loss 105.6772, val loss 96.5670
# epoch  18, train loss 77.2044, val loss 98.9962
# epoch  19, train loss 105.7535, val loss 106.9448
# epoch  20, train loss 100.8892, val loss 97.1748
# epoch  21, train loss 68.7890, val loss 91.0119
# epoch  22, train loss 100.5464, val loss 101.4719
# epoch  23, train loss 118.7288, val loss 98.0252
# epoch  24, train loss 111.8951, val loss 100.6082
# epoch  25, train loss 107.3420, val loss 106.2713
# epoch  26, train loss 99.6545, val loss 91.9305
# epoch  27, train loss 122.9224, val loss 97.2035
# epoch  28, train loss 154.5742, val loss 101.8311
# epoch  29, train loss 125.8676, val loss 97.1994
# epoch  30, train loss 72.0250, val loss 92.3141
# epoch  31, train loss 107.8514, val loss 94.8040
# epoch  32, train loss 72.2944, val loss 96.7376
# epoch  33, train loss 88.2067, val loss 97.8107
# epoch  34, train loss 71.6370, val loss 94.4187
# epoch  35, train loss 68.0983, val loss 94.1560
# epoch  36, train loss 67.6238, val loss 102.9011
# epoch  37, train loss 152.6943, val loss 96.2267
# epoch  38, train loss 92.6788, val loss 95.3716
# epoch  39, train loss 109.6107, val loss 93.3925
# epoch  40, train loss 99.6482, val loss 92.4748
# epoch  41, train loss 80.0365, val loss 93.9757
# epoch  42, train loss 125.0454, val loss 89.8625
# epoch  43, train loss 104.7029, val loss 92.2176
# epoch  44, train loss 95.9112, val loss 96.1903
# epoch  45, train loss 121.0489, val loss 91.9978
# epoch  46, train loss 39.0573, val loss 95.1685
# epoch  47, train loss 80.5278, val loss 94.7409
# epoch  48, train loss 68.4115, val loss 98.6406
# epoch  49, train loss 123.3238, val loss 95.4271
# epoch  50, train loss 102.1217, val loss 87.8513
# epoch  51, train loss 110.9143, val loss 92.4554
# epoch  52, train loss 68.9610, val loss 91.2084
# epoch  53, train loss 79.0217, val loss 94.2553
# epoch  54, train loss 118.0779, val loss 90.5544
# epoch  55, train loss 54.0356, val loss 92.7865
# epoch  56, train loss 119.3101, val loss 93.1921
# epoch  57, train loss 79.8174, val loss 92.6910
# epoch  58, train loss 101.0575, val loss 91.4389
# epoch  59, train loss 72.4125, val loss 91.2360
# epoch  60, train loss 98.1358, val loss 93.9138
# epoch  61, train loss 97.8735, val loss 92.0439
# epoch  62, train loss 89.1403, val loss 99.9672
# epoch  63, train loss 166.6564, val loss 94.6729
# epoch  64, train loss 91.2614, val loss 91.4509
# epoch  65, train loss 86.0087, val loss 99.1797
# epoch  66, train loss 42.9589, val loss 90.1401
# epoch  67, train loss 62.0169, val loss 88.2416
# epoch  68, train loss 130.5099, val loss 91.3920
# epoch  69, train loss 93.8702, val loss 89.3753
# epoch  70, train loss 78.2368, val loss 92.9558
# epoch  71, train loss 106.6512, val loss 91.6531
# epoch  72, train loss 82.7237, val loss 96.3232
# epoch  73, train loss 56.6857, val loss 91.6632
# epoch  74, train loss 61.5404, val loss 89.0966
# epoch  75, train loss 89.4474, val loss 93.0972
# epoch  76, train loss 58.0731, val loss 92.5816
# epoch  77, train loss 83.5175, val loss 95.7240
# epoch  78, train loss 106.8062, val loss 95.8378
# epoch  79, train loss 115.9406, val loss 96.2297
# epoch  80, train loss 90.9012, val loss 92.2906
# epoch  81, train loss 61.4868, val loss 91.7196
# epoch  82, train loss 136.0218, val loss 92.8684
# epoch  83, train loss 49.6944, val loss 91.2391
# epoch  84, train loss 84.4224, val loss 92.9256
# epoch  85, train loss 49.0095, val loss 92.0982
# epoch  86, train loss 47.6095, val loss 89.7092
# epoch  87, train loss 90.8873, val loss 89.0493
# epoch  88, train loss 48.8447, val loss 94.4122
# epoch  89, train loss 62.3787, val loss 91.4527
# epoch  90, train loss 142.7929, val loss 88.5114
# epoch  91, train loss 124.2319, val loss 92.7061
# epoch  92, train loss 83.2818, val loss 95.2245
# epoch  93, train loss 79.7251, val loss 95.1086
# epoch  94, train loss 62.4201, val loss 88.5282
# epoch  95, train loss 116.4363, val loss 95.0502
# epoch  96, train loss 65.6520, val loss 92.4732
# epoch  97, train loss 78.6297, val loss 87.9531
# epoch  98, train loss 136.7650, val loss 98.6273
# epoch  99, train loss 83.4028, val loss 90.9790
# epoch 100, train loss 79.5888, val loss 90.4411
# epoch 101, train loss 126.2801, val loss 94.2754
# epoch 102, train loss 144.5209, val loss 86.0461
# epoch 103, train loss 94.5427, val loss 91.3714
# epoch 104, train loss 118.3216, val loss 91.1824
# epoch 105, train loss 115.6274, val loss 88.4632
# epoch 106, train loss 96.9250, val loss 90.5816
# epoch 107, train loss 97.8681, val loss 88.7827
# epoch 108, train loss 76.5791, val loss 87.7233
# epoch 109, train loss 125.7146, val loss 90.3499
# epoch 110, train loss 104.1469, val loss 89.3709
# epoch 111, train loss 148.8791, val loss 92.0343
# epoch 112, train loss 78.1666, val loss 90.6369
# epoch 113, train loss 126.4186, val loss 92.5117
# epoch 114, train loss 106.6682, val loss 89.8951
# epoch 115, train loss 79.8488, val loss 90.3716
# epoch 116, train loss 90.5075, val loss 90.7632
# epoch 117, train loss 85.3892, val loss 93.3096
# epoch 118, train loss 72.2310, val loss 91.0155
# epoch 119, train loss 103.2234, val loss 91.4939
# epoch 120, train loss 67.3545, val loss 93.2579
# epoch 121, train loss 102.6846, val loss 90.2037
# epoch 122, train loss 105.2238, val loss 90.8637
# epoch 123, train loss 84.0301, val loss 91.9526
# epoch 124, train loss 66.1451, val loss 88.5120
# epoch 125, train loss 69.5837, val loss 94.0517
# epoch 126, train loss 77.0899, val loss 90.1822
# epoch 127, train loss 74.4502, val loss 91.9286
# epoch 128, train loss 69.9991, val loss 91.0125
# epoch 129, train loss 145.1370, val loss 89.4908
# epoch 130, train loss 88.4738, val loss 93.3473
# epoch 131, train loss 37.7641, val loss 90.5119
# epoch 132, train loss 107.7507, val loss 85.4493
# epoch 133, train loss 89.0519, val loss 92.2558
# epoch 134, train loss 118.0382, val loss 88.7230
# epoch 135, train loss 78.1216, val loss 93.7159
# epoch 136, train loss 97.2575, val loss 91.1594
# epoch 137, train loss 81.1632, val loss 92.8027
# epoch 138, train loss 86.0991, val loss 91.6359
# epoch 139, train loss 98.5466, val loss 90.7875
# epoch 140, train loss 69.3021, val loss 92.9858
# epoch 141, train loss 126.7780, val loss 84.6997
# epoch 142, train loss 107.2871, val loss 93.8332
# epoch 143, train loss 123.2533, val loss 93.7739
# epoch 144, train loss 106.6443, val loss 91.2235
# epoch 145, train loss 114.0774, val loss 90.1119
# epoch 146, train loss 98.7323, val loss 90.7214
# epoch 147, train loss 137.4196, val loss 94.3935
# epoch 148, train loss 90.2310, val loss 93.0442
# epoch 149, train loss 64.7646, val loss 87.0682
# epoch 150, train loss 76.9272, val loss 87.1574
# epoch 151, train loss 121.1189, val loss 89.7462
# epoch 152, train loss 63.8047, val loss 90.8967
# epoch 153, train loss 32.6037, val loss 87.3118
# epoch 154, train loss 146.2555, val loss 95.4814
# epoch 155, train loss 74.1962, val loss 89.7901
# epoch 156, train loss 131.2050, val loss 91.2849
# epoch 157, train loss 138.2605, val loss 91.2026
# epoch 158, train loss 70.2770, val loss 88.9054
# epoch 159, train loss 52.8599, val loss 93.2168
# epoch 160, train loss 88.5469, val loss 86.4471
# epoch 161, train loss 64.2750, val loss 93.4949
# epoch 162, train loss 105.3624, val loss 92.2760
# epoch 163, train loss 68.1486, val loss 89.3545
# epoch 164, train loss 93.0637, val loss 95.5908
# epoch 165, train loss 90.9758, val loss 93.1210
# epoch 166, train loss 91.4755, val loss 96.8078
# epoch 167, train loss 93.0013, val loss 87.0575
# epoch 168, train loss 41.3481, val loss 95.4358
# epoch 169, train loss 132.3901, val loss 91.8652
# epoch 170, train loss 64.6662, val loss 90.5925
# epoch 171, train loss 78.5948, val loss 88.9761
# epoch 172, train loss 75.4436, val loss 92.4829
# epoch 173, train loss 71.0634, val loss 89.1889
# epoch 174, train loss 109.9925, val loss 95.9140
# epoch 175, train loss 101.7136, val loss 88.0630
# epoch 176, train loss 53.4091, val loss 88.2946
# epoch 177, train loss 153.1379, val loss 92.8726
# epoch 178, train loss 61.2690, val loss 87.5378
# epoch 179, train loss 92.5724, val loss 92.2204
# epoch 180, train loss 68.4257, val loss 89.0267
# epoch 181, train loss 142.5513, val loss 93.8704
# epoch 182, train loss 108.3027, val loss 92.6808
# epoch 183, train loss 137.4525, val loss 88.0157
# epoch 184, train loss 132.2854, val loss 88.5953
# epoch 185, train loss 70.7737, val loss 91.9260
# epoch 186, train loss 43.6155, val loss 88.9771
# epoch 187, train loss 88.7949, val loss 91.7621
# epoch 188, train loss 83.9132, val loss 90.3359
# epoch 189, train loss 90.5653, val loss 87.7077
# epoch 190, train loss 101.7718, val loss 89.8325
# epoch 191, train loss 104.6631, val loss 89.6754
# epoch 192, train loss 115.8949, val loss 93.1339
# epoch 193, train loss 101.0555, val loss 92.4733
# epoch 194, train loss 114.0997, val loss 92.4894
# epoch 195, train loss 125.1770, val loss 90.6097
# epoch 196, train loss 80.5401, val loss 92.0499
# epoch 197, train loss 68.6270, val loss 94.7472
# epoch 198, train loss 89.5451, val loss 93.7038
# epoch 199, train loss 80.6089, val loss 91.6421
